# %%
import pandas as pd

# %%
data = pd.read_excel('data/[동아출판] 6차_최종납품본_20240314_13331건.xlsx', sheet_name='Sheet1')

# %%
col_name = ['문항ID', '출처_학교급', '출처_학년', '출처_학기', '출처_과목', '출처_교육과정', '출처_시리즈/브랜드',
       '출처_제품명', '출처_페이지','출처-문제번호', '출처_판형', '저자', '발행처정보', '사용기한', '사용범위', '사용권리',
       '내용_교육과정', '내용_학교급', '내용_교과', '내용_학년(군)', '성취기준_영역(대)_연번', '성취기준_영역(대)',
       '성취기준_영역(중)_연번', '성취기준_영역(중)', '성취기준_성취기준명_연번', '성취기준_성취기준명',
       '성취기준_표준코드', 'KC1', 'KC2', '키워드', '행동영역', '난이도', '지문(세트문제)', '발문', '객관식선지1',
       '객관식선지2', '객관식선지3', '객관식선지4', '객관식선지5', '객관식정답', '주관식정답입력개수', '주관식정답_1',
       '주관식정답_2', '주관식정답_3', '주관식정답_4', '주관식정답_5', '주관식정답_6', '주관식정답_7',
       '주관식정답_8', '주관식정답_9', '주관식정답_10', '주관식정답_11', '주관식정답_12', '주관식정답_13',
       '주관식정답_14', '주관식정답_15', '주관식정답_16', '주관식정답_17', '주관식정답_18', '주관식정답_19',
       '주관식정답_20', '풀이', '평가기준1(서술형)', '평가기준1(퍼센트)', '평가기준2(서술형)',
       '평가기준2(퍼센트)', '평가기준3(서술형)', '평가기준3(퍼센트)', 
       '평가기준4(서술형)', '평가기준4(퍼센트)', '평가기준5(서술형)', '평가기준5(퍼센트)', '문제유형', '선택지유형',
       '선택지개수', '세트문제여부', '개별출제여부','세트문항 대표ID', '딸린문항수', '교과서1_교육과정', '교과서1_학교급',
       '교과서1_학년', '교과서1_학기', '교과서1_교과서명', '교과서1_저자', '교과서1_대단원순서', '교과서1_대단원명',
       '교과서1_중단원순서', '교과서1_중단원명', '교과서1_소단원순서', '교과서1_소단원명', '교과서2_교육과정',
       '교과서2_학교급', '교과서2_학년', '교과서2_학기', '교과서2_교과서명', '교과서2_저자', '교과서2_대단원순서',
       '교과서2_대단원명', '교과서2_중단원순서', '교과서2_중단원명', '교과서2_소단원순서', '교과서2_소단원명','memo']
data.columns = col_name

# %%
ju =

# %%
data['객관식정답'].replace({'1': '①', '2': '②', '3': '③', '4': '④', '5': '⑤',1: '①', 2: '②', 3: '③',4: '④',5: '⑤'}, regex=True, inplace=True)
ans = data[['객관식정답','주관식정답_1', '주관식정답_2', '주관식정답_3', '주관식정답_4', '주관식정답_5', '주관식정답_6', '주관식정답_7',
       '주관식정답_8', '주관식정답_9', '주관식정답_10', '주관식정답_11', '주관식정답_12', '주관식정답_13',
       '주관식정답_14', '주관식정답_15', '주관식정답_16', '주관식정답_17', '주관식정답_18', '주관식정답_19', '주관식정답_20']]
ans.fillna('')
ans_values=[]

for index, row in ans.iterrows():
    ans_values.append( '정답: '+' <span style="color:red">//</span> '.join(str(value) for value in row.dropna()) )

# %%
ans_values
# Out:
# ['정답: $152$ // $140$',
#  '정답: 풀이 참조',
#  '정답: $76$ // $105$',
#  '정답: 풀이 참조',
#  '정답: $21$ // $30$ // $20$',
#  '정답: $13$ // $12$ // $15$',
#  '정답: $45$ // $50$',
#  '정답: 이상 // 미만',
#  '정답: 초과 // 이하',
#  '정답: $25$ // $50$',
#  '정답: $350$',
#  '정답: 풀이 참조',
#  '정답: $160$',
#  '정답: $300$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 약 $3480$명',
#  '정답: 풀이 참조',
#  '정답: $5$',
#  '정답: 풀이 참조',
#  '정답: $9$',
#  '정답: $3600$',
#  '정답: $7900$',
#  '정답: $2000$',
#  '정답: $6000$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $4$ // $4$ // $20$ // $3$ // $6$ // $2$ // $3$',
#  '정답: $9$ // $9$ // $2$ // $\\dfrac{18}{7}$ // $2 \\dfrac{4}{7}$',
#  '정답: $8$ // $3$ // $8$ // $3$ // $2$ // $2$ // $3$',
#  '정답: $6$ // $5$ // $6$ // $5$ // $18$ // $5$ // $3$ // $3$ // $5$',
#  '정답: $1$ // $5$ // $3$ // $3$ // $5$ // $3$ // $3$ // $5$',
#  '정답: $15$ // $4$ // $\\dfrac{15}{4}$ // $3 \\dfrac{3}{4}$',
#  '정답: $3$ // $4$ // $3$ // $4$ // $\\dfrac{15}{4}$ // $3\\dfrac{3}{4}$',
#  '정답: $4$  // $3$  // $3$  // $4$  // $\\dfrac{15}{4}$ // $3 \\dfrac{3}{4}$',
#  '정답: $1$ // $1$ // $7$',
#  '정답: $6$ // $1$ // $6$ // $1$ // $6$',
#  '정답: $2$ // $3$ // $1$ // $6$ // $1$ // $6$',
#  '정답: $2$ // $1$ // $6$ // $1$ // $6$',
#  '정답: $17$ // $17$ // $85$ // $14$ // $1$',
#  '정답: $5$ // $8$ // $5$ // $8$',
#  '정답: $5$ // $11$ // $22$ // $4$ // $2$ // $5$',
#  '정답: $18 \\dfrac{1}{3}$',
#  '정답: $3$ // $4$ // $1$ // $12$',
#  '정답: $3$ // $1$ // $4$ // $5$ // $3$ // $20$',
#  '정답: $5$ // $3$ // $5$ // $27$',
#  '정답: 풀이 참조',
#  '정답: $3$ // $5$ // ${9}$ // $40$',
#  '정답: $5$ // $18$ // $5$',
#  '정답: $1$ // $8$ // $1$ // $24$',
#  '정답: $9$ // $3$ // $10$ // $27$ // $400$',
#  '정답: $3$ // $3$ // $21$ // $2$ // $5$',
#  '정답: $15$',
#  '정답: $200$',
#  '정답: $\\dfrac{2}{3}$',
#  '정답: $\\dfrac{8}{15}$',
#  '정답: $240 \\mathrm{~cm}^{2}$',
#  '정답: 풀이 참조',
#  '정답: $8, 9, 72$ (또는 $9, 8, 72$)',
#  '정답: ㅁ // ㅂ',
#  '정답: ㅁㅂ // ㅂㄱ',
#  '정답: 풀이 참조',
#  '정답: ㄹㅁㅂ // ㅁㅂㄱ // ㅁㄹㄷ',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $3.12$',
#  '정답: $14.8$',
#  '정답: $1.62$',
#  '정답: $64.8$',
#  '정답: $0.8$ // $0.7$',
#  '정답: $0.01$',
#  '정답: $56$ // $0.56$',
#  '정답: $0.45$',
#  '정답: $13.78$',
#  '정답: $0.49$',
#  '정답: $0.152$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $17.1 \\mathrm{~m}$ // $15.3 \\mathrm{~m}$',
#  '정답: $261.63 \\mathrm{~m}^{2}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 다 // 라',
#  '정답: 라',
#  '정답: 풀이 참조',
#  '정답: 전개도',
#  '정답: 실선 // 점선',
#  '정답: $6$개',
#  '정답: $12$개',
#  '정답: $8$개',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 면 ㄱㄴㅂㅁ // 면 ㄱㄴㄷㄹ // 면 ㄱㅁㅇㄹ',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나 // 라 // 바',
#  '정답: $76$',
#  '정답: $76$ // $19$',
#  '정답: $4$ // $6$ // $5$',
#  '정답: 모둠 $2$',
#  '정답: $28$ // $25$ // $5$',
#  '정답: $24$ // $120$',
#  '정답: $120$ // $11$ // $39$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 민형',
#  '정답: 민형 // 선재 // 혜주',
#  '정답: ㉠',
#  '정답: ㉢',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 희수 // 재영 // 지원',
#  '정답: $143.0 \\mathrm{~cm}$ // $145.2 \\mathrm{~cm}$ // $157.0 \\mathrm{~cm}$',
#  '정답: 연수 // 지훈',
#  '정답: $37$권 // $34$권',
#  '정답: $430$ // $<$ // $500$',
#  '정답: $1200$ // $<$ // $1230$',
#  '정답: $300$ // $<$ // $310$',
#  '정답: $1700$ // $=$ // $1700$',
#  '정답: 버림  // 반올림 // 올림',
#  '정답: 서준',
#  '정답: $>$',
#  '정답: $<$',
#  '정답: $\\displaystyle\\frac{3}{4}$',
#  '정답: $\\displaystyle\\frac{3}{5}$',
#  '정답: $96$쪽',
#  '정답: $2 \\dfrac{4}{15}$',
#  '정답: $\\dfrac{5}{28}$',
#  '정답: $7 \\mathrm{~cm}$',
#  '정답: $55^{\\circ}$',
#  '정답: $8$ // $115$',
#  '정답: $40$ // $9$',
#  '정답: $6 \\mathrm{cm}$',
#  '정답: $3 \\mathrm{cm}$',
#  '정답: $2.8$',
#  '정답: $4.5$',
#  '정답: $0.72$',
#  '정답: $2.92$',
#  '정답: $4$',
#  '정답: $3.5$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $12.6$',
#  '정답: $14.4$',
#  '정답: $12.57$',
#  '정답: $36.25$',
#  '정답: $7.2$',
#  '정답: $10.2$',
#  '정답: $9.2$',
#  '정답: $35.7$',
#  '정답: $36.8$',
#  '정답: $15.6$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $12.9\\mathrm{m}$',
#  '정답: 나 // 라',
#  '정답: 가 // 마 // 바',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: ㅌㅋ // ㅁㅂ',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $5$ // $4$ // $15$ // $3 \\dfrac{3}{4}$',
#  '정답: $6$ // $7$ // $24$ // $3 \\dfrac{3}{7}$',
#  '정답: $5$ // $16$ // $5$ // $16$',
#  '정답: $1$ // $2$ // $5$ // $16$',
#  '정답: $1$ // $2$ // $5$ // $16$',
#  '정답: $\\displaystyle\\frac{2}{63}$',
#  '정답: $7$ // $3$ // $7$ // $3$ // $1$ // $2$',
#  '정답: $1$ // $8$ // $1$ // $40$',
#  '정답: $2 \\dfrac{1}{10}$',
#  '정답: ㅇ // ㅅ // ㅂ // ㅁ',
#  '정답: ㅇㅅ // ㅅㅂ // ㅂㅁ // ㅁㅊ // ㅇㅈ',
#  '정답: ㅅㅇㅈ // ㅇㅅㅂ // ㅅㅂㅁ // ㅂㅁㅊ',
#  '정답: 풀이 참조',
#  '정답: $80$ // $4$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $1$ // $36$ // $36$',
#  '정답: $9$ // $10$ // $36$ // $0.36$',
#  '정답: $9$ // $100$ // $36$ // $0.036$',
#  '정답: $9$ // $100$ // $36$ // $0.0036$',
#  '정답: $1.6$',
#  '정답: $0.527$',
#  '정답: $3$ // $9$ // $2$ // $1$ // $4$',
#  '정답: $2$ // $1$ // $12$ // $1$ // $12$ // $1$ // $2$',
#  '정답: $3$ // $3$ // $2$ // $9$ // $4$ // $1$ // $2$',
#  '정답: $4$ // $3$ // $8$ // $15$',
#  '정답: $11$ // $3$ // $33$ // $4$ // $1$ // $8$',
#  '정답: $7$ // $35$',
#  '정답: $35$ // $108$',
#  '정답: $>$',
#  '정답: $7$ 또는 $8$ // $8$ 또는 $7$',
#  '정답: 마',
#  '정답: 가 // 나 // 라',
#  '정답: $5 \\mathrm{cm}$',
#  '정답: $3 \\mathrm{cm}$',
#  '정답: $30^{\\circ}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $25$ // $20$ // $3$ // $75$ // $3$ // $25$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $5$ // $6$ // $0$ // $20$ // $3$ // $0$ // $0$ // $100$ // $3$ // $7$ // $5$',
#  '정답: 풀이 참조',
#  '정답: $1$ // $6$ // $0$ // $10$ // $2$ // $4$ // $0$ // $0$ // $400$ // $2$ // $4$ // $6$ // $6$',
#  '정답: $4200$ // $591$ // $7$ // $4137$',
#  '정답: $271 \\times 6=1626$ // $1626$명',
#  '정답: $650 \\times 7=4550$ // $4550$원',
#  '정답: $55 \\times 80=4400$ // $4400 \\mathrm{~cm}$',
#  '정답: $45$개',
#  '정답: $630$개',
#  '정답: $87 \\div 6=14 \\cdots 3 $ // $14$ // $3$',
#  '정답: $8$ // $50$ // $50$묶음',
#  '정답: $6$ // $3$ // $4$ // $6$ // $3$',
#  '정답: $11$ // $6$ // $7$ // $11$ // $6$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 진',
#  '정답: 가',
#  '정답: 진',
#  '정답: 가',
#  '정답: $<$',
#  '정답: $<$',
#  '정답: $>$',
#  '정답: $=$',
#  '정답: 풀이 참조',
#  '정답: $9000$',
#  '정답: $3850$',
#  '정답: $5$ // $20$',
#  '정답: $\\mathrm{L}$ ',
#  '정답: $\\mathrm{mL}$',
#  '정답: $\\mathrm{mL}$',
#  '정답: $6$ // $300$',
#  '정답: $2$ // $400$',
#  '정답: 풀이 참조',
#  '정답: $2$ // $400$',
#  '정답: $1$',
#  '정답: $\\mathrm{kg}$',
#  '정답: $\\mathrm{g}$',
#  '정답: $\\mathrm{t}$',
#  '정답: $7$ // $200$',
#  '정답: $7$ // $500$',
#  '정답: 수영장',
#  '정답: 풀이 참조',
#  '정답: $5$ // $7$ // $4$ // $8$ // $24$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $5$ // $4$ // $9$ // $1$ // $2$',
#  '정답: 풀이 참조',
#  '정답: $5$ // $2$ // $5$ // $2$ // $3$',
#  '정답: $1$ // $4$ // $2$ // $1$ // $3$ // $3$ // $3$',
#  '정답: $11$ // $10$ // $21$ // $3$ // $3$',
#  '정답: $7 \\dfrac{3}{5}$',
#  '정답: $5 \\dfrac{4}{10}$',
#  '정답: $3 \\dfrac{3}{7}$',
#  '정답: $7 \\dfrac{4}{9}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $2 \\dfrac{4}{8}$',
#  '정답: $2 \\dfrac{3}{10}$',
#  '정답: $5 \\dfrac{2}{5}$',
#  '정답: $2 \\dfrac{4}{13}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $4 \\dfrac{6}{8}$',
#  '정답: $6\\dfrac{2}{5}$',
#  '정답: $5\\dfrac{1}{7}$',
#  '정답: $4\\dfrac{5}{9}$',
#  '정답: $1 \\dfrac{3}{4}$',
#  '정답: $2 \\dfrac{3}{5}$',
#  '정답: $3 \\dfrac{4}{7}$',
#  '정답: $\\dfrac{6}{10}$',
#  '정답: $\\displaystyle\\frac{5}{7}$',
#  '정답: $\\displaystyle\\frac{6}{9}$',
#  '정답: $1 \\displaystyle\\frac{1}{8}\\left(=\\displaystyle\\frac{9}{8}\\right)$',
#  '정답: $1 \\displaystyle\\frac{5}{10}\\left(=\\displaystyle\\frac{15}{10}\\right)$',
#  '정답: $7$ // $3$ // $4$',
#  '정답: $6$ // $2$ // $4$',
#  '정답: $\\dfrac 3 6$',
#  '정답: $\\dfrac 3 9$',
#  '정답: $\\dfrac 1 3$',
#  '정답: $\\dfrac{4}{12}$',
#  '정답: $2$ // $3$ // $3$ // $3$ // $5$ // $1$ // $2$ // $6$ // $2$',
#  '정답: $11$ // $15$ // $26$ // $6$ // $2$',
#  '정답: $4 \\dfrac{2}{3}$',
#  '정답: $3 \\dfrac{7}{8}\\left(=\\dfrac{31}{8}\\right)$',
#  '정답: $7 \\dfrac{4}{12}$',
#  '정답: $8 \\dfrac{7}{15}$',
#  '정답: 풀이 참조',
#  '정답: $3 \\dfrac{7}{10}$',
#  '정답: $2 \\dfrac{1}{4}\\left(=\\dfrac{9}{4}\\right)$',
#  '정답: $5 \\dfrac{3}{8}$',
#  '정답: $7 \\dfrac{1}{5}$',
#  '정답: $7 \\dfrac{6}{7}$',
#  '정답: $\\dfrac{6}{8}$',
#  '정답: $2 \\dfrac{8}{9}$',
#  '정답: $3 \\dfrac{5}{11}$',
#  '정답: $3 \\dfrac{6}{9}$',
#  '정답: $1 \\dfrac{2}{6}\\left(=\\dfrac{8}{6}\\right)$',
#  '정답: $3\\dfrac1 5\\rm{~kg}$',
#  '정답: $1 \\dfrac{3}{5}$ // $3 \\dfrac{1}{5}$',
#  '정답: $1 \\dfrac{3}{5} \\mathrm{~kg}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나 // 다 // 바 // 사 // 아 // 가 // 라 // 마',
#  '정답: 다 // 바',
#  '정답: 이등변삼각형 // 정삼각형',
#  '정답: 가 // 라 // 바 // 아 // 나 // 사 // 다 // 마',
#  '정답: 예각삼각형 // 둔각삼각형',
#  '정답: ⑤',
#  '정답: 나 // 바 // 마 // 라 // 다 // 가',
#  '정답: 풀이 참조',
#  '정답: $150^{\\circ}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $0.45$',
#  '정답: $1.45$ // 일 점 사오',
#  '정답: $1.45\\rm ~m$',
#  '정답: 풀이 참조',
#  '정답: $1$ // $5$ // $2$ // $6$',
#  '정답: 일 // $0.5$ // 소수 둘째 // 소수 셋째 // $0.006$',
#  '정답: 풀이 참조',
#  '정답: $>$',
#  '정답: $2.43$',
#  '정답: $5.19$',
#  '정답: 일 // $7$',
#  '정답: 소수 셋째 // $0.009$',
#  '정답: $0.7$',
#  '정답: 풀이 참조',
#  '정답: $1.2$',
#  '정답: $0.3$',
#  '정답: 풀이 참조',
#  '정답: $0.5\\mathrm{~L}$',
#  '정답: $0.57$',
#  '정답: $1.88$',
#  '정답: $0.37$',
#  '정답: $0.27$',
#  '정답: $0.27 \\mathrm{~m}$',
#  '정답: $0.64$',
#  '정답: $3.53$',
#  '정답: $0.4$',
#  '정답: $2.1$',
#  '정답: $1.2$',
#  '정답: $4.3$',
#  '정답: $0.36$',
#  '정답: $3.93$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $21.18$ // $5.51$',
#  '정답: 풀이 참조',
#  '정답: 수직',
#  '정답: ③',
#  '정답: ㉡',
#  '정답: $90^{\\circ}$',
#  '정답: 평행선 사이의 거리',
#  '정답: 풀이 참조',
#  '정답: 가 // 다 // 마 // 나 // 라',
#  '정답: 다 // 마 // 사다리꼴',
#  '정답: 다, 마 // 가, 나, 라',
#  '정답: 나 // 나 // 평행사변형',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나 // 다 // 라 // 나 // 라',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $12$장',
#  '정답: $2$ // $570$',
#  '정답: $2$ // $981$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $14$일',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $22 \\mathrm{~mL}$',
#  '정답: 풀이 참조',
#  '정답: 가 // 다',
#  '정답: 풀이 참조',
#  '정답: 가',
#  '정답: 나 // 다',
#  '정답: 나 // 라',
#  '정답: 풀이 참조',
#  '정답: 변',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $5$개',
#  '정답: $2$개',
#  '정답: 나 // 다',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $3$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 바',
#  '정답: $50000$(또는 $5$만) // 오만',
#  '정답: $25030$(또는 $2$만 $5030$) // 이만 오천삼십',
#  '정답: 사만 오백삼십오',
#  '정답: $23900$',
#  '정답: $40000$',
#  '정답: $700$',
#  '정답: 풀이 참조',
#  '정답: 50',
#  '정답: 120',
#  '정답: ④',
#  '정답: 풀이 참조',
#  '정답: $100$',
#  '정답: $195$',
#  '정답: $65$',
#  '정답: $85$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $30^{\\circ}$',
#  '정답: $150^{\\circ}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $5$개',
#  '정답: $14000$ // $70$',
#  '정답: $72$',
#  '정답: 풀이 참조',
#  '정답: $985$ // $24$',
#  '정답: $41$ // $1$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $1905$ // $1270$ // $1905$ // $1270$ // $14605$',
#  '정답: 풀이 참조',
#  '정답: ㉰',
#  '정답: ㉮',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 다릅니다.',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 시계 반대 // $90$ // 시계 // $180$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $1$',
#  '정답: 풀이 참조',
#  '정답: $1$',
#  '정답: $2$ // $4$ // $6$',
#  '정답: 풀이 참조',
#  '정답: $8$개',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나',
#  '정답: 풀이 참조',
#  '정답: $53061000$ // 오천삼백육만 천',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $11220$원',
#  '정답: ㉰',
#  '정답: ㉯',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 다릅니다. ',
#  '정답: 전력량 // $90$ // 채원 // 현우 // 재희 // 선경',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $80$대 // $60$대',
#  '정답: 풀이 참조',
#  '정답: ④',
#  '정답: $373$',
#  '정답: $834$',
#  '정답: $963$',
#  '정답: $1341$',
#  '정답: $442$',
#  '정답: $317$',
#  '정답: $231$',
#  '정답: $382$',
#  '정답: $447$',
#  '정답: $426$',
#  '정답: $289$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 각 ㄹㅁㅂ 또는 각 ㅂㅁㄹ',
#  '정답: 변 ㅁㄹ 또는 반직선 ㅁㄹ // 변 ㅁㅂ 또는 반직선 ㅁㅂ',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: ⑤',
#  '정답: 풀이 참조',
#  '정답: 위인 // 학생 수',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $2$ // $5$',
#  '정답: 풀이 참조',
#  '정답: $7$ // $2$',
#  '정답: $3$',
#  '정답: $45$ // $5$',
#  '정답: $16-8-8=0$',
#  '정답: $36-9-9-9-9=0$',
#  '정답: $5$ // $15$',
#  '정답: $3$ // $5$',
#  '정답: $15$ // $3$',
#  '정답: $14$ // $7$',
#  '정답: $7$ // $2$',
#  '정답: $6$ // $6$',
#  '정답: $6$ // $6$',
#  '정답: $9$ // $9$ // $9$',
#  '정답: $6$ // $6$ // $6$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $6$ // $6$봉지에 담을 수 있습니다.',
#  '정답: $6$ // $6$개씩 담을 수 있습니다.',
#  '정답: $\\boxed{\\phantom{0}} \\div 3=8$ // $24$',
#  '정답: 풀이 참조',
#  '정답: $7 \\mathrm{cm}$',
#  '정답: $10$개',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $30$ // $6$',
#  '정답: ①,④',
#  '정답: 풀이 참조',
#  '정답: $<$',
#  '정답: 풀이 참조',
#  '정답: 수영',
#  '정답: $8$',
#  '정답: $42$',
#  '정답: 풀이 참조',
#  '정답: $8$ // $80$',
#  '정답: $56$ // $560$',
#  '정답: $2$ // $20$ // $2$ // $4$ // $24$',
#  '정답: $180$ // $6$ // $186$',
#  '정답: $200$ // $8$ // $208$',
#  '정답: $126$',
#  '정답: $166$',
#  '정답: $213$',
#  '정답: $279$',
#  '정답: $96$',
#  '정답: $392$',
#  '정답: ㉡',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: ㉡ // ㉣ // ㉠ // ㉢',
#  '정답: $42$ // $84$',
#  '정답: 풀이 참조',
#  '정답: $89$',
#  '정답: $136$',
#  '정답: $72$',
#  '정답: $288$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $1 \\mathrm{km}~500 \\mathrm{m}$',
#  '정답: 풀이 참조',
#  '정답: $100$',
#  '정답: $170$',
#  '정답: $3$ // $30$',
#  '정답: $5$ // $50$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $6$ // $35$ // $60$ // $6$ // $36$',
#  '정답: $9$ // $34$ // $58$',
#  '정답: $1$ // $40$ // $3$ // $32$',
#  '정답: 풀이 참조',
#  '정답: ㉠',
#  '정답: 주연 // 용준 // 수호',
#  '정답: 현욱',
#  '정답: 풀이 참조',
#  '정답: $7$시 $42$분 $12$초',
#  '정답: 풀이 참조',
#  '정답: ㉢ // ㉠ // ㉡',
#  '정답: 현서',
#  '정답: $3$시 $15$분',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $>$',
#  '정답: $>$',
#  '정답: $>$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 모두 틀립니다.',
#  '정답: 풀이 참조',
#  '정답: $<$',
#  '정답: 풀이 참조',
#  '정답: $8$번',
#  '정답: $1$ // $8$',
#  '정답: $9$ // $3$ // $9$ // $3$',
#  '정답: $3$ // $3$',
#  '정답: 풀이 참조',
#  '정답: $1$ // $1$ // $3$ // $1$ // $1$ // $3$',
#  '정답: $5$ // $2$ // $5$ // $2$ // $2$ // $1$ // $2$',
#  '정답: $1 \\dfrac{3}{4}$',
#  '정답: $1 \\dfrac{4}{7}$',
#  '정답: $3$',
#  '정답: $6$ // $2$ // $6$ // $2$ // $3$',
#  '정답: $2$',
#  '정답: $4 \\dfrac{2}{3}$',
#  '정답: $5$ // $5$',
#  '정답: $10$ // $2$ // $10$ // $2$ // $5$',
#  '정답: $2$',
#  '정답: $3$',
#  '정답: 풀이 참조',
#  '정답: $9$ // $7$ // $9$ // $7$ // $1\\dfrac{2}{7}$',
#  '정답: $8$ // $5$ // $8$ // $5$ // $1\\dfrac{3}{5}$',
#  '정답: $1 \\dfrac{1}{2}$',
#  '정답: $1 \\dfrac{5}{7}$',
#  '정답: 풀이 참조',
#  '정답: $12$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $4$ // $5$ // $10$',
#  '정답: $2$ // $9$ // $45$',
#  '정답: $4$ // $3$ // $4$ // $3$ // $8$ // $21$',
#  '정답: $11$ // $66$ // $25$ // $66$ // $25$ // $2\\dfrac{16}{25}$',
#  '정답: $11$ // $11$ // $6$ // $5$ // $66$ // $25$ // $2\\dfrac{16}{25}$',
#  '정답: $\\displaystyle2 \\frac{18}{35}$',
#  '정답: $\\displaystyle5 \\frac{5}{8}$',
#  '정답: 풀이 참조',
#  '정답: $5$ // $9$ // $9$ // $5$',
#  '정답: $8$ // $3$ // $40$ // $33$ // $1 \\dfrac{7}{33}$',
#  '정답: $1 \\dfrac{25}{27}$',
#  '정답: $2 \\dfrac{3}{4}$',
#  '정답: 풀이 참조',
#  '정답: ㉡',
#  '정답: $8$ // $9$ // $2$ // $9$ // $4$',
#  '정답: $\\dfrac{12}{17} \\div \\dfrac{4}{17}=3$ // $3$봉지',
#  '정답: $=$',
#  '정답: $7$ // $8$ // $3$ // $8$ // $7$ // $9$ // $3$ // $9$',
#  '정답: $2$',
#  '정답: $\\dfrac{25}{27}$배',
#  '정답: 풀이 참조',
#  '정답: 은지',
#  '정답: $4 \\div \\dfrac 2 7 =14$ // $14$명',
#  '정답: ㉢ // ㉠ // ㉡ // ㉣',
#  '정답: $1 \\dfrac{29}{70} \\rm{cm}$',
#  '정답: 풀이 참조',
#  '정답: $7$개',
#  '정답: 약 $28 \\mathrm{g}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $9 \\dfrac{1}{6}$',
#  '정답: 풀이 참조',
#  '정답: $7$',
#  '정답: 풀이 참조',
#  '정답: $>$',
#  '정답: $9$ // $3$ // $3$',
#  '정답: ㉢ // ㉡ // ㉠',
#  '정답: 풀이 참조',
#  '정답: $\\dfrac{3}{8}$배',
#  '정답: $2 \\dfrac{3}{16}$',
#  '정답: 풀이 참조',
#  '정답: $\\dfrac{11}{24} \\mathrm{m}$',
#  '정답: 풀이 참조',
#  '정답: $27$ // $9$',
#  '정답: $29$ // $9$ // $27$ // $9$ // $3$',
#  '정답: $3$',
#  '정답: $294$ // $42$ // $7$',
#  '정답: $7$ // $7$',
#  '정답: $144$ // $12$ // $144$ // $12$ // $12$',
#  '정답: 풀이 참조',
#  '정답: $19$ // $11$',
#  '정답: $147$ // $6$',
#  '정답: $6$ // $48$',
#  '정답: $5$ // $175$',
#  '정답: $6.4$ // $24$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $477$ // $90$ // $477$ // $90$ // $5.3$',
#  '정답: $5.3$ // $450$ // $270$ // $270$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $200$ // $25$ // $8$',
#  '정답: $8$ // $200$',
#  '정답: 풀이 참조',
#  '정답: $3$',
#  '정답: $2.8$',
#  '정답: $2.83$',
#  '정답: $4$ // $20$ // $1.8$',
#  '정답: $4$명',
#  '정답: $1.8 \\rm{kg}$',
#  '정답: $420$ // $35$ // $420$ // $35$ // $12$',
#  '정답: $12$ // $35$ // $70$ // $70$',
#  '정답: 풀이 참조',
#  '정답: $77$ // $770$ // $7700$',
#  '정답: $13.29$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $4.2$',
#  '정답: $5.3$',
#  '정답: $4$ // $16$ // $1.6$ // $4$ // $1.6$',
#  '정답: 풀이 참조',
#  '정답: $15.4$ // $0.7$ // $22$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: ㉡',
#  '정답: $22 \\div 1.3=16.9 \\cdots \\cdots$ // $17$분',
#  '정답: $7$배 // $5$배',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $9$ // $63$ // $4.4$ // $9$ // $4.4$',
#  '정답: ㉠ // ㉢ // ㉡',
#  '정답: 풀이 참조',
#  '정답: $13$ // $1.5$',
#  '정답: 풀이 참조',
#  '정답: $7$',
#  '정답: 풀이 참조',
#  '정답: $16$개',
#  '정답: $7$개',
#  '정답: $6$개',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나',
#  '정답: $6$개',
#  '정답: $3$ // $2$ // $2$ // $1$',
#  '정답: 풀이 참조',
#  '정답: $9$개',
#  '정답: $8$개',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 가 // 마 // 사',
#  '정답: 나 // 다 // 라 // 바 // 아',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 연우 // 지희 // 민규',
#  '정답: 나',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $6$개',
#  '정답: 가 // 나',
#  '정답: 풀이 참조',
#  '정답: 호연',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 다',
#  '정답: $8$가지',
#  '정답: 가 // 나 // 다 // 라',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $17$개',
#  '정답: 풀이 참조',
#  '정답: 가 // 다',
#  '정답: 풀이 참조',
#  '정답: 나 // 다',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 가 // 나',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 다 // 나',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $2$가지',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 나',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 가 // 나',
#  '정답: 풀이 참조',
#  '정답: 다',
#  '정답: 다',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $19$ // $31$',
#  '정답: 곱하여도',
#  '정답: 풀이 참조',
#  '정답: $24$ // $12$ // $6$ // $4$',
#  '정답: 풀이 참조',
#  '정답: $2:5$',
#  '정답: $8:3$',
#  '정답: $4:3$',
#  '정답: $0.35$ // $29$ // $35$',
#  '정답: $5$ // $24$ // $8$ // $15$',
#  '정답: $6$ // $77$ // $11$ // $42$',
#  '정답: $8$ // $5$ // $40$ // $25$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $210$',
#  '정답: $90$',
#  '정답: $90\\rm{g}$',
#  '정답: 풀이 참조',
#  '정답: $3$ // $8$ // $5$ // $3$ // $5$ // $5$ // $8$',
#  '정답: $3$ // $15$ // $5$ // $25$',
#  '정답: $8$ // $1$ // $8$ // $4$ // $2$ // $8$',
#  '정답: ㉠ ',
#  '정답: $3$',
#  '정답: $8$ // $10$',
#  '정답: $16$ // $40$',
#  '정답: $27$ // $18$',
#  '정답: $4$ // $5$ // $48$ // $1$ // $5$ // $12$',
#  '정답: $5000$원',
#  '정답: 풀이 참조',
#  '정답: 나 // 라',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $9: 8$',
#  '정답: 풀이 참조',
#  '정답: $7$ // $3$ // $7$ // $3$',
#  '정답: $7: 6$',
#  '정답: 비율',
#  '정답: 민규',
#  '정답: 풀이 참조',
#  '정답: $3$ // $4$ // $12$',
#  '정답: ㉡ // ㉢',
#  '정답: $10$ // $4$',
#  '정답: ㉡',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $28$장',
#  '정답: $36$개 // $27$개',
#  '정답: 풀이 참조',
#  '정답: $5$ // $9$ // $20$ // $9$ // $36$ // $9$ // $180$ // $20$ // $20$',
#  '정답: $6$조각 // $2$조각',
#  '정답: $28 \\mathrm{cm}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $11$ // $10$',
#  '정답: $4$ // $12$ // $3$ // $16$',
#  '정답: $5$ // $14$ // $70$ // $7$ // $10$ // $70$',
#  '정답: $3$ // $1$ // $3$ // $4$ // $21$ // $3$ // $1$ // $1$ // $4$ // $7$',
#  '정답: $8$',
#  '정답: $8$ // $18$',
#  '정답: $14: 13$',
#  '정답: 풀이 참조',
#  '정답: $7:2$',
#  '정답: 풀이 참조',
#  '정답: $10000$원 // $8000$원',
#  '정답: $40$분',
#  '정답: ㉡',
#  '정답: $5:4$',
#  '정답: 풀이 참조',
#  '정답: $450 \\mathrm{mL}$',
#  '정답: 풀이 참조',
#  '정답: $3.14$ // $3.14$ // $3.14$',
#  '정답: $3.14$배',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $3.14$',
#  '정답: $15$ // $25$',
#  '정답: $10$ // $10$ // $50$',
#  '정답: $10$ // $10$ // $100$',
#  '정답: $50$ // $100$',
#  '정답: $60$',
#  '정답: $88$',
#  '정답: $60$ // $88$',
#  '정답: 풀이 참조',
#  '정답: $4$ // $4$ // $48$',
#  '정답: $3.1$ // $11$ // $11$ // $375.1$',
#  '정답: $3$ // $2$ // $2$ // $12$ // $3$ // $4$ // $4$ // $12$ // $48$ // $12$ // $36$',
#  '정답: $4$ // $3.1$ // $4$ // $4$ // $49.6$',
#  '정답: $49\\rm{cm}^2$',
#  '정답: $81\\rm{cm}^2$',
#  '정답: 풀이 참조',
#  '정답: $6$ // $6$ // $4$ // $8$ // $6$ // $8$',
#  '정답: 풀이 참조',
#  '정답: $3.1$ // $3.14$',
#  '정답: $65.1 \\mathrm{cm}$',
#  '정답: $43.4 \\mathrm{cm}$',
#  '정답: $800 \\mathrm{cm}^{2}$',
#  '정답: $1600 \\mathrm{cm}^{2}$',
#  '정답: $800$ // $1600$',
#  '정답: $32$ // $60$ // (예) $46$',
#  '정답: 풀이 참조',
#  '정답: $251.1 \\mathrm{cm}^{2}$',
#  '정답: 풀이 참조',
#  '정답: $2826 \\mathrm{cm}^{2}$',
#  '정답: $8$ // $3$ // $3$ // $198.4$ // $27.9$ // $170.5$',
#  '정답: $20$ // $10$ // $400$ // $314$ // $86$',
#  '정답: $216 \\mathrm{cm}^{2}$',
#  '정답: $131.88\\rm{cm}^2$',
#  '정답: $3$ // $4$ // $14$',
#  '정답: 풀이 참조',
#  '정답: 은주 // 민희',
#  '정답: $3.1 \\mathrm{cm}$',
#  '정답: $35\\rm{cm}$',
#  '정답: $36$ // $48$',
#  '정답: ㉡ // ㉠ // ㉢',
#  '정답: $432 \\mathrm{cm}^{2}$',
#  '정답: $75.95 \\mathrm{cm}^{2}$',
#  '정답: 풀이 참조',
#  '정답: $706.5 \\mathrm{m}^{2}$',
#  '정답: $28\\rm{cm}^{2}$ // $28.26\\rm{cm}^{2}$',
#  '정답: 풀이 참조',
#  '정답: $21$ // $45$',
#  '정답: $36 \\mathrm{cm}^{2}$',
#  '정답: $942 \\mathrm{m}^{2}$',
#  '정답: ㉠',
#  '정답: $32 \\mathrm{cm}$',
#  '정답: ㉡ // ㉣ // ㉠ // ㉢',
#  '정답: 풀이 참조',
#  '정답: 다',
#  '정답: 풀이 참조',
#  '정답: $10$ // $3.14$ // $31.4$',
#  '정답: $13 \\mathrm{cm}$',
#  '정답: 구',
#  '정답: 원 // 원',
#  '정답: 가 // 다 // 마',
#  '정답: 풀이 참조',
#  '정답: $10 \\mathrm{cm}$ // $7 \\mathrm{cm}$',
#  '정답: $\\bigcirc$',
#  '정답: 풀이 참조',
#  '정답: $5 \\mathrm{cm}$  // $18.6 \\mathrm{cm}$',
#  '정답: 풀이 참조',
#  '정답: 풀이 참조',
#  '정답: $6 \\mathrm{cm}$ // $8 \\mathrm{cm}$ // $10 \\mathrm{cm}$',
#  '정답: $3 \\mathrm{cm}$ // $4 \\mathrm{cm}$',
#  ...]
